# %%
# =========================================================
# SmartChat Insight
# Análisis de los datos, clientes (recurrentes, perdidos) y productos
# =========================================================

# Importar librerías
import re
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# Definir rutas
clean_path = Path("../data/cleaned/whatsapp_clean.csv")
output_path = Path("../data/outputs/")
output_path.mkdir(parents=True, exist_ok=True)

# Cargar datos limpios
df = pd.read_csv(clean_path)
df["date"] = pd.to_datetime(df["date"], errors="coerce")

print("Datos cargados correctamente")
print(f"Total de mensajes: {len(df)}")
df.head(5)
# Out:
# Datos cargados correctamente
# Total de mensajes: 17841
#         date         time                user  \
# 0 2025-10-25  12:47 p. m.   +1 (772) 800-8661
# 1 2025-10-25  12:47 p. m.  Vidrios Y Fachadas
# 2 2025-10-25  12:47 p. m.   +1 (772) 800-8661
# 3 2025-10-25   3:00 p. m.  Vidrios Y Fachadas
# 4 2025-10-25   3:00 p. m.  Vidrios Y Fachadas
#
#                                              message  \
# 0                                              Hola!
# 1  Bienvenido, conoce nuestra variedad de productos:
# 2  Estoy buscando ventanas corredizas en aluminio...
# 3                                           Si señor
# 4                                     Se las tenemos
#
#                                     file_name
# 0  Chat de WhatsApp con +1 (772) 800-8661.txt
# 1  Chat de WhatsApp con +1 (772) 800-8661.txt
# 2  Chat de WhatsApp con +1 (772) 800-8661.txt
# 3  Chat de WhatsApp con +1 (772) 800-8661.txt
# 4  Chat de WhatsApp con +1 (772) 800-8661.txt

# %%
# Pasar todo a minúsculas
df["clean_message"] = df["message"].str.lower()

# Eliminar puntuación básica
df["clean_message"] = df["clean_message"].apply(lambda x: re.sub(r"[^a-záéíóúüñ0-9\s]", "", x))

# %%
def remove_emojis(text):
    return re.sub(r"[^\w\s.,!?áéíóúüñÁÉÍÓÚÜÑ]", "", str(text))

# %%
df["message"] = df["message"].apply(remove_emojis)

# %%
df
# Out:
#             date         time                user  \
# 0     2025-10-25  12:47 p. m.   +1 (772) 800-8661
# 1     2025-10-25  12:47 p. m.  Vidrios Y Fachadas
# 2     2025-10-25  12:47 p. m.   +1 (772) 800-8661
# 3     2025-10-25   3:00 p. m.  Vidrios Y Fachadas
# 4     2025-10-25   3:00 p. m.  Vidrios Y Fachadas
# ...          ...          ...                 ...
# 17836 2025-05-30   5:52 p. m.  Vidrios Y Fachadas
# 17837 2025-05-31   8:16 a. m.  Vidrios Y Fachadas
# 17838 2025-05-31   8:16 a. m.  Vidrios Y Fachadas
# 17839 2025-05-31  10:37 a. m.     edidcastazapata
# 17840 2025-05-31  10:38 a. m.     edidcastazapata
#
#                                                  message  \
# 0                                                  Hola!
# 1       Bienvenido, conoce nuestra variedad de productos
# 2      Estoy buscando ventanas corredizas en aluminio...
# 3                                               Si señor
# 4                                         Se las tenemos
# ...

# %% [markdown]
# Por fines de investigación, se analiza si es posible llegar a los productos por medio de las palabras más frecuentes:

# %%
from collections import Counter
import nltk
from nltk.corpus import stopwords


nltk.download("stopwords")
stopwords_es = set(stopwords.words("spanish"))

# Dividir en palabras y eliminar stopwords
all_words = [
    word for msg in df["clean_message"].dropna()
    for word in msg.split()
    if word not in stopwords_es and len(word) > 2
]

# Contar palabras más comunes
word_counts = Counter(all_words)
pd.DataFrame(word_counts.most_common(30), columns=["word", "count"])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#           word  count
# 0   multimedia   3645
# 1      omitido   3645
# 2       buenos   1107
# 3      gracias    765
# 4         hola    714
# 5         días    698
# 6       buenas    596
# 7       tardes    541
# 8        listo    519
# 9         dias    450
# 10       señor    410
# 11         don    395
# 12       favor    360
# 13     mensaje    332
# 14      mañana    292
# 15      muchas    287
# 16       gusto    278
# 17      julian    273
# 18        doña    266
# 19     momento    265
# 20        bien    261
# 21       usted    261
# 22  cotización    244
# 23    servicio    215
# 24   productos    205
# 25   encuentra    205
# 26      conoce    203
# 27  bienvenido    202
# 28    variedad    202
# 29        mijo    202

# %%
import nltk
from nltk.corpus import stopwords

print("Total stopwords:", len(stopwords.words("spanish")))
# Out:
# Total stopwords: 313
# <WordListCorpusReader in '/root/nltk_data/corpora/stopwords'>
