# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielaaguiv5/ProyectoFinal2/blob/main/notebooks/Compilado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================================
#  SmartChat Insight
#  Limpieza y estructuración de archivos .txt exportados de WhatsApp
# =========================================================

# Importar librerías necesarias
import re
import pandas as pd
from pathlib import Path

# Definir ruta de entrada y salida
raw_path = Path("../data/raw_chats/")
clean_path = Path("../data/cleaned/")
clean_path.mkdir(parents=True, exist_ok=True)

# Función para leer y limpiar un archivo de chat
def parse_whatsapp_chat(file_path):
    """
    Convierte un archivo .txt exportado de WhatsApp en un DataFrame estructurado.
    Columnas: date, time, user, message
    """
    pattern = re.compile(r"^(\d{1,2}/\d{1,2}/\d{2,4}), (\d{1,2}:\d{2}\s?[ap]\.?\s?m\.?) - (.*?): (.*)")
    data = []

    with open(file_path, encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            match = pattern.match(line)
            if match:
                date, time, user, message = match.groups()
                data.append([date, time, user.strip(), message.strip()])

    df = pd.DataFrame(data, columns=["date", "time", "user", "message"])
    return df

# Procesar todos los archivos .txt en la carpeta data/raw_chats/
all_chats = []
for file in raw_path.glob("*.txt"):
    print(f"Procesando {file.name} ...")
    df_chat = parse_whatsapp_chat(file)
    df_chat["file_name"] = file.name
    all_chats.append(df_chat)
all_chats
# Out:
# Procesando Chat de WhatsApp con +1 (772) 800-8661.txt ...
# Procesando Chat de WhatsApp con +34 610 94 76 16.txt ...
# Procesando Chat de WhatsApp con +51 924 523 653.txt ...
# Procesando Chat de WhatsApp con +57 300 2258585.txt ...
# Procesando Chat de WhatsApp con +57 300 3542763.txt ...
# Procesando Chat de WhatsApp con +57 300 3580743.txt ...
# Procesando Chat de WhatsApp con +57 300 3861858.txt ...
# Procesando Chat de WhatsApp con +57 300 5157021.txt ...
# Procesando Chat de WhatsApp con +57 300 5215647.txt ...
# Procesando Chat de WhatsApp con +57 300 5251823.txt ...
# Procesando Chat de WhatsApp con +57 300 5594233.txt ...
# Procesando Chat de WhatsApp con +57 300 5986430.txt ...
# Procesando Chat de WhatsApp con +57 300 5999973.txt ...
# Procesando Chat de WhatsApp con +57 300 6167701.txt ...
# Procesando Chat de WhatsApp con +57 300 6560668.txt ...
# Procesando Chat de WhatsApp con +57 300 6599837.txt ...
# Procesando Chat de WhatsApp con +57 300 7377282.txt ...
# Procesando Chat de WhatsApp con +57 300 8061069.txt ...
# Procesando Chat de WhatsApp con +57 300 8541609.txt ...
# Procesando Chat de WhatsApp con +57 300 8718740.txt ...
# Procesando Chat de WhatsApp con +57 300 9525755.txt ...
# Procesando Chat de WhatsApp con +57 301 2643467.txt ...
# Procesando Chat de WhatsApp con +57 301 2814295.txt ...
# Procesando Chat de WhatsApp con +57 301 3447499.txt ...
# Procesando Chat de WhatsApp con +57 301 3512805.txt ...
# Procesando Chat de WhatsApp con +57 301 4025990.txt ...
# Procesando Chat de WhatsApp con +57 301 4105437.txt ...
# Procesando Chat de WhatsApp con +57 301 4473862.txt ...
# Procesando Chat de WhatsApp con +57 301 4942056.txt ...
# Procesando Chat de WhatsApp con +57 301 5015637.txt ...
# Procesando Chat de WhatsApp con +57 301 5728537.txt ...
# Procesando Chat de WhatsApp con +57 301 5912191.txt ...
# Procesando Chat de WhatsApp con +57 301 6598941.txt ...
# Procesando Chat de WhatsApp con +57 301 6930326.txt ...
# Procesando Chat de WhatsApp con +57 301 6985639.txt ...
# Procesando Chat de WhatsApp con +57 301 7399855.txt ...
# Procesando Chat de WhatsApp con +57 301 7934532.txt ...
# Procesando Chat de WhatsApp con +57 301 8431653.txt ...
# Procesando Chat de WhatsApp con +57 301 9030642.txt ...
# Procesando Chat de WhatsApp con +57 302 2497196.txt ...
# Procesando Chat de WhatsApp con +57 302 2721677.txt ...
# Procesando Chat de WhatsApp con +57 302 3553974.txt ...
# Procesando Chat de WhatsApp con +57 302 3718607.txt ...
# Procesando Chat de WhatsApp con +57 302 4020703.txt ...
# Procesando Chat de WhatsApp con +57 302 8506687.txt ...
# Procesando Chat de WhatsApp con +57 304 2727483.txt ...
# Procesando Chat de WhatsApp con +57 304 4054681.txt ...
# Procesando Chat de WhatsApp con +57 304 4914813.txt ...
# Procesando Chat de WhatsApp con +57 304 6610301.txt ...
# Procesando Chat de WhatsApp con +57 304 6694462.txt ...
# Procesando Chat de WhatsApp con +57 304 6772157.txt ...
# Procesando Chat de WhatsApp con +57 305 3531112.txt ...
# Procesando Chat de WhatsApp con +57 305 3534106.txt ...
# Procesando Chat de WhatsApp con +57 305 3775378.txt ...
# Procesando Chat de WhatsApp con +57 305 3802101.txt ...
# Procesando Chat de WhatsApp con +57 305 4458728.txt ...
# Procesando Chat de WhatsApp con +57 305 4471249.txt ...
# Procesando Chat de WhatsApp con +57 310 2577555.txt ...
# Procesando Chat de WhatsApp con +57 310 2771631.txt ...
# Procesando Chat de WhatsApp con +57 310 3042129.txt ...
# Procesando Chat de WhatsApp con +57 310 3241532.txt ...
# Procesando Chat de WhatsApp con +57 310 3445842.txt ...
# Procesando Chat de WhatsApp con +57 310 3589981.txt ...
# Procesando Chat de WhatsApp con +57 310 3647034.txt ...
# Procesando Chat de WhatsApp con +57 310 3854113.txt ...
# Procesando Chat de WhatsApp con +57 310 4095659.txt ...
# Procesando Chat de WhatsApp con +57 310 4444335.txt ...
# Procesando Chat de WhatsApp con +57 310 4497758.txt ...
# Procesando Chat de WhatsApp con +57 310 4560770.txt ...
# Procesando Chat de WhatsApp con +57 310 4987420.txt ...
# Procesando Chat de WhatsApp con +57 310 5017329.txt ...
# Procesando Chat de WhatsApp con +57 310 5169285.txt ...
# Procesando Chat de WhatsApp con +57 310 5596519.txt ...
# Procesando Chat de WhatsApp con +57 310 6318725.txt ...
# Procesando Chat de WhatsApp con +57 310 6731885.txt ...
# Procesando Chat de WhatsApp con +57 310 7050765.txt ...
# Procesando Chat de WhatsApp con +57 310 7133084.txt ...
# Procesando Chat de WhatsApp con +57 310 8307071.txt ...
# Procesando Chat de WhatsApp con +57 310 8481641.txt ...
# Procesando Chat de WhatsApp con +57 311 2581629.txt ...
# Procesando Chat de WhatsApp con +57 311 3025717.txt ...
# Procesando Chat de WhatsApp con +57 311 3052268.txt ...
# Procesando Chat de WhatsApp con +57 311 3213989.txt ...
# Procesando Chat de WhatsApp con +57 311 3273310.txt ...
# Procesando Chat de WhatsApp con +57 311 6092615.txt ...
# Procesando Chat de WhatsApp con +57 311 6287863.txt ...
# Procesando Chat de WhatsApp con +57 311 7454736.txt ...
# Procesando Chat de WhatsApp con +57 311 7752329.txt ...
# Procesando Chat de WhatsApp con +57 311 7824003.txt ...
# Procesando Chat de WhatsApp con +57 311 7931714.txt ...
# Procesando Chat de WhatsApp con +57 311 7945277.txt ...
# Procesando Chat de WhatsApp con +57 311 8830041.txt ...
# Procesando Chat de WhatsApp con +57 311 8989768.txt ...
# Procesando Chat de WhatsApp con +57 312 2193870.txt ...
# Procesando Chat de WhatsApp con +57 312 2235753.txt ...
# Procesando Chat de WhatsApp con +57 312 2279282.txt ...
# Procesando Chat de WhatsApp con +57 312 2319501.txt ...
# Procesando Chat de WhatsApp con +57 312 2771182.txt ...
# Procesando Chat de WhatsApp con +57 312 4579966.txt ...
# Procesando Chat de WhatsApp con +57 312 4760812.txt ...
# Procesando Chat de WhatsApp con +57 312 5638817.txt ...
# Procesando Chat de WhatsApp con +57 312 5758045.txt ...
# Procesando Chat de WhatsApp con +57 312 7114755.txt ...
# Procesando Chat de WhatsApp con +57 312 7598049.txt ...
# Procesando Chat de WhatsApp con +57 312 8344833.txt ...
# Procesando Chat de WhatsApp con +57 312 8433158.txt ...
# Procesando Chat de WhatsApp con +57 312 8726715.txt ...
# Procesando Chat de WhatsApp con +57 312 8881339.txt ...
# Procesando Chat de WhatsApp con +57 313 2870143.txt ...
# Procesando Chat de WhatsApp con +57 313 4156728.txt ...
# Procesando Chat de WhatsApp con +57 313 5907050.txt ...
# Procesando Chat de WhatsApp con +57 313 6200465.txt ...
# Procesando Chat de WhatsApp con +57 313 6349533.txt ...
# Procesando Chat de WhatsApp con +57 313 6696451.txt ...
# Procesando Chat de WhatsApp con +57 313 6860721.txt ...
# Procesando Chat de WhatsApp con +57 313 7417324.txt ...
# Procesando Chat de WhatsApp con +57 313 8495715.txt ...
# Procesando Chat de WhatsApp con +57 313 8587035.txt ...
# Procesando Chat de WhatsApp con +57 314 3728040.txt ...
# Procesando Chat de WhatsApp con +57 314 3945987.txt ...
# Procesando Chat de WhatsApp con +57 314 4408607.txt ...
# Procesando Chat de WhatsApp con +57 314 4521021.txt ...
# Procesando Chat de WhatsApp con +57 314 4863136.txt ...
# Procesando Chat de WhatsApp con +57 314 5121991.txt ...
# Procesando Chat de WhatsApp con +57 314 5407342.txt ...
# Procesando Chat de WhatsApp con +57 314 5513464.txt ...
# Procesando Chat de WhatsApp con +57 314 6309700.txt ...
# Procesando Chat de WhatsApp con +57 314 6325373.txt ...
# Procesando Chat de WhatsApp con +57 314 7230047.txt ...
# Procesando Chat de WhatsApp con +57 314 8853838.txt ...
# Procesando Chat de WhatsApp con +57 314 8950277.txt ...
# Procesando Chat de WhatsApp con +57 315 2423797.txt ...
# Procesando Chat de WhatsApp con +57 315 5061407.txt ...
# Procesando Chat de WhatsApp con +57 315 5269287.txt ...
# Procesando Chat de WhatsApp con +57 315 6067937.txt ...
# Procesando Chat de WhatsApp con +57 315 6384228.txt ...
# Procesando Chat de WhatsApp con +57 315 6388278.txt ...
# Procesando Chat de WhatsApp con +57 315 6990298.txt ...
# Procesando Chat de WhatsApp con +57 315 8248061.txt ...
# Procesando Chat de WhatsApp con +57 316 2928777.txt ...
# Procesando Chat de WhatsApp con +57 316 2947263.txt ...
# Procesando Chat de WhatsApp con +57 316 4086476.txt ...
# Procesando Chat de WhatsApp con +57 316 4101310.txt ...
# Procesando Chat de WhatsApp con +57 316 4234492.txt ...
# Procesando Chat de WhatsApp con +57 316 4678854.txt ...
# Procesando Chat de WhatsApp con +57 316 4802640.txt ...
# Procesando Chat de WhatsApp con +57 316 5230036.txt ...
# Procesando Chat de WhatsApp con +57 316 5275580.txt ...
# Procesando Chat de WhatsApp con +57 316 5619977.txt ...
# Procesando Chat de WhatsApp con +57 317 6458790.txt ...
# Procesando Chat de WhatsApp con +57 317 8937239.txt ...
# Procesando Chat de WhatsApp con +57 318 2151671.txt ...
# Procesando Chat de WhatsApp con +57 318 4535486.txt ...
# Procesando Chat de WhatsApp con +57 318 5483408.txt ...
# Procesando Chat de WhatsApp con +57 318 5577088.txt ...
# Procesando Chat de WhatsApp con +57 318 8032098.txt ...
# Procesando Chat de WhatsApp con +57 318 8954202.txt ...
# Procesando Chat de WhatsApp con +57 319 2896444.txt ...
# Procesando Chat de WhatsApp con +57 319 3114829.txt ...
# Procesando Chat de WhatsApp con +57 319 5353926.txt ...
# Procesando Chat de WhatsApp con +57 320 5341389.txt ...
# Procesando Chat de WhatsApp con +57 320 6424971.txt ...
# Procesando Chat de WhatsApp con +57 320 6652603.txt ...
# Procesando Chat de WhatsApp con +57 320 7598788.txt ...
# Procesando Chat de WhatsApp con +57 320 7996487.txt ...
# Procesando Chat de WhatsApp con +57 320 8507130.txt ...
# Procesando Chat de WhatsApp con +57 321 3104091.txt ...
# Procesando Chat de WhatsApp con +57 321 3169173.txt ...
# Procesando Chat de WhatsApp con +57 321 3293171.txt ...
# Procesando Chat de WhatsApp con +57 321 4007107.txt ...
# Procesando Chat de WhatsApp con +57 321 5819701.txt ...
# Procesando Chat de WhatsApp con +57 321 5859019.txt ...
# Procesando Chat de WhatsApp con +57 321 6296833.txt ...
# Procesando Chat de WhatsApp con +57 321 6346045.txt ...
# Procesando Chat de WhatsApp con +57 321 6739353.txt ...
# Procesando Chat de WhatsApp con +57 321 7159114.txt ...
# Procesando Chat de WhatsApp con +57 321 7452544.txt ...
# Procesando Chat de WhatsApp con +57 321 8013565.txt ...
# Procesando Chat de WhatsApp con +57 321 9451601.txt ...
# Procesando Chat de WhatsApp con +57 321 9585149.txt ...
# Procesando Chat de WhatsApp con +57 322 3635106.txt ...
# Procesando Chat de WhatsApp con +57 322 6193322.txt ...
# Procesando Chat de WhatsApp con +57 322 8688473.txt ...
# Procesando Chat de WhatsApp con +57 323 2296388.txt ...
# Procesando Chat de WhatsApp con +57 323 5803966.txt ...
# Procesando Chat de WhatsApp con +57 323 8078859.txt ...
# Procesando Chat de WhatsApp con +57 324 3242456.txt ...
# Procesando Chat de WhatsApp con +57 324 3409668.txt ...
# Procesando Chat de WhatsApp con +57 324 4056666.txt ...
# Procesando Chat de WhatsApp con +57 324 4610848.txt ...
# Procesando Chat de WhatsApp con +57 324 5735952.txt ...
# Procesando Chat de WhatsApp con +57 324 6210937.txt ...
# Procesando Chat de WhatsApp con +57 350 4626046.txt ...
# Procesando Chat de WhatsApp con +57 350 6101096.txt ...
# Procesando Chat de WhatsApp con +57 350 6370522.txt ...
# Procesando Chat de WhatsApp con +57 350 8947677.txt ...
# Procesando Chat de WhatsApp con +90 539 721 69 03.txt ...
# Procesando Chat de WhatsApp con ACp Gris.txt ...
# Procesando Chat de WhatsApp con Adriana Casa Girardota Lote 55.txt ...
# Procesando Chat de WhatsApp con Adriana Piedrahita Reyes.txt ...
# Procesando Chat de WhatsApp con Alberto Chamo.txt ...
# Procesando Chat de WhatsApp con Alejandra Urán ADH.txt ...
# Procesando Chat de WhatsApp con Alejandro peludo.txt ...
# Procesando Chat de WhatsApp con Alejandro Trabajador De Javier.txt ...
# Procesando Chat de WhatsApp con Alejo Curazzao.txt ...
# Procesando Chat de WhatsApp con Anderson Alexis Ruales Barbosa.txt ...
# Procesando Chat de WhatsApp con Andrea Dávila.txt ...
# Procesando Chat de WhatsApp con Andres Felipe Instalador.txt ...
# Procesando Chat de WhatsApp con Andres Giraldo seial.txt ...
# Procesando Chat de WhatsApp con Anggie Otalvaro.txt ...
# Procesando Chat de WhatsApp con Argencol Cocinas sas.txt ...
# Procesando Chat de WhatsApp con Arquitecto Darwin.txt ...
# Procesando Chat de WhatsApp con Barrios Javier.txt ...
# Procesando Chat de WhatsApp con Bienes Con Futuro.txt ...
# Procesando Chat de WhatsApp con Biviana DeOssa.txt ...
# Procesando Chat de WhatsApp con Camilo Perez.txt ...
# Procesando Chat de WhatsApp con Carlos Andrés Londoño M..txt ...
# Procesando Chat de WhatsApp con Carlos Mira Cabinas Santa Rosa De Osos.txt ...
# Procesando Chat de WhatsApp con Carlos Zapata.txt ...
# Procesando Chat de WhatsApp con Catalina Herrera.txt ...
# Procesando Chat de WhatsApp con Cerralum Ejf Sas Faysury.txt ...
# Procesando Chat de WhatsApp con Cheril Urrego Excelec Int.txt ...
# Procesando Chat de WhatsApp con Claudia Pisent.txt ...
# Procesando Chat de WhatsApp con Comercial Prisma Acrílicos.txt ...
# Procesando Chat de WhatsApp con Compresores A Domicilio.txt ...
# Procesando Chat de WhatsApp con Conecta.txt ...
# Procesando Chat de WhatsApp con Cotizaciones Hercas.txt ...
# Procesando Chat de WhatsApp con Cámara De Comercio De Medellín.txt ...
# Procesando Chat de WhatsApp con daissabodegabog.txt ...
# Procesando Chat de WhatsApp con Daniel Las Vegas.txt ...
# Procesando Chat de WhatsApp con Daniel P Esposo De Juliana Acusticas.txt ...
# Procesando Chat de WhatsApp con David Transporte.txt ...
# Procesando Chat de WhatsApp con Deqc.txt ...
# Procesando Chat de WhatsApp con Durafull.txt ...
# Procesando Chat de WhatsApp con edidcastazapata.txt ...
# Procesando Chat de WhatsApp con Eduardo Pintura Negro Mate.txt ...
# Procesando Chat de WhatsApp con Eleçtrico Cocacola.txt ...
# Procesando Chat de WhatsApp con Erik Rodríguez Gt Provenza.txt ...
# Procesando Chat de WhatsApp con ERREKA COLOMBIA,.txt ...
# Procesando Chat de WhatsApp con Esteban Plegable.txt ...
# Procesando Chat de WhatsApp con Eugenia Castillo Berrocal Vontadora.txt ...
# Procesando Chat de WhatsApp con Ever Miranda.txt ...
# Procesando Chat de WhatsApp con Fabián Vitelsa Personal.txt ...
# Procesando Chat de WhatsApp con Felipe Arango.txt ...
# Procesando Chat de WhatsApp con Fernando Gutiérrez QUID SAS Cliente Daissa.txt ...
# Procesando Chat de WhatsApp con Ferrosvel SAS.txt ...
# Procesando Chat de WhatsApp con Gabriel Echeverry - Ducasse Industrial.txt ...
# Procesando Chat de WhatsApp con Gabriel Plásticos Truher.txt ...
# Procesando Chat de WhatsApp con Gerencia Lleras Green.txt ...
# Procesando Chat de WhatsApp con German Molina.txt ...
# Procesando Chat de WhatsApp con Gestión contable y administrativa Acusticos.txt ...
# Procesando Chat de WhatsApp con Guillermo Inmobiliaria.txt ...
# Procesando Chat de WhatsApp con Gustavo Pelaez Cliente Acusticas.txt ...
# Procesando Chat de WhatsApp con Hector Montoya Apto Belen.txt ...
# Procesando Chat de WhatsApp con HERRAJES Y DISEÑO S. A. S.txt ...
# Procesando Chat de WhatsApp con Ikon Construcciones.txt ...
# Procesando Chat de WhatsApp con Isabel Cristina Mejia.txt ...
# Procesando Chat de WhatsApp con Jarol Conductor.txt ...
# Procesando Chat de WhatsApp con Javier Pelaez.txt ...
# Procesando Chat de WhatsApp con Jhon Fredy.txt ...
# Procesando Chat de WhatsApp con Jhon Mario.txt ...
# Procesando Chat de WhatsApp con Johana MOOD.txt ...
# Procesando Chat de WhatsApp con Johana OspinaDevimar.txt ...
# Procesando Chat de WhatsApp con Jorge Ivan Giraldo.txt ...
# Procesando Chat de WhatsApp con Jose Arquitecto CC Santa fe.txt ...
# Procesando Chat de WhatsApp con Jose Belmonte.txt ...
# Procesando Chat de WhatsApp con Juan Alvarez.txt ...
# Procesando Chat de WhatsApp con Juan David.txt ...
# Procesando Chat de WhatsApp con Juan Diego Arquitecto.txt ...
# Procesando Chat de WhatsApp con Juan Fernando Escobar.txt ...
# Procesando Chat de WhatsApp con Juan Franco.txt ...
# Procesando Chat de WhatsApp con Juan Rafael Supervisor AM.txt ...
# Procesando Chat de WhatsApp con Juli Mejia.txt ...
# Procesando Chat de WhatsApp con Juliana Acusticas.txt ...
# Procesando Chat de WhatsApp con Ky.txt ...
# Procesando Chat de WhatsApp con Larry Stwar Lizcano Peña.txt ...
# Procesando Chat de WhatsApp con Lau.txt ...
# Procesando Chat de WhatsApp con Lina Henao~.txt ...
# Procesando Chat de WhatsApp con Lleras Green.txt ...
# Procesando Chat de WhatsApp con Lucas.txt ...
# Procesando Chat de WhatsApp con Luis Francisco.txt ...
# Procesando Chat de WhatsApp con Luisa Agudelo.txt ...
# Procesando Chat de WhatsApp con Luisa Devimar.txt ...
# Procesando Chat de WhatsApp con Luz  Helena Rag.txt ...
# Procesando Chat de WhatsApp con Luz Estella.txt ...
# Procesando Chat de WhatsApp con Martha Arroyave.txt ...
# Procesando Chat de WhatsApp con Martin Transporte.txt ...
# Procesando Chat de WhatsApp con Mauricio CarBot.txt ...
# Procesando Chat de WhatsApp con Mauro Escobar.txt ...
# Procesando Chat de WhatsApp con MauRo París Ventana Acustica.txt ...
# Procesando Chat de WhatsApp con MG SAS 3173644876.txt ...
# Procesando Chat de WhatsApp con Moni Quintero 💫.txt ...
# Procesando Chat de WhatsApp con Mruiz.txt ...
# Procesando Chat de WhatsApp con Mónica Llavera Mood.txt ...
# Procesando Chat de WhatsApp con Natalia Fonseca KOI.txt ...
# Procesando Chat de WhatsApp con Nathy Barrera.txt ...
# Procesando Chat de WhatsApp con Nelson 🥏.txt ...
# Procesando Chat de WhatsApp con Oficina 2.txt ...
# Procesando Chat de WhatsApp con Paula Cabinas Los Balsos.txt ...
# Procesando Chat de WhatsApp con Pecoso 2.txt ...
# Procesando Chat de WhatsApp con Priduccion Hercas.txt ...
# Procesando Chat de WhatsApp con Rapividrios SAS.txt ...
# Procesando Chat de WhatsApp con Ricardo Residente KOI.txt ...
# Procesando Chat de WhatsApp con Ronaldo Lleras Green.txt ...
# Procesando Chat de WhatsApp con Sainc.txt ...
# Procesando Chat de WhatsApp con Sebas Tello Topo.txt ...
# Procesando Chat de WhatsApp con Sebastián Cardona.txt ...
# Procesando Chat de WhatsApp con Secretaría Apa.txt ...
# Procesando Chat de WhatsApp con Slendy koi.txt ...
# Procesando Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR.txt ...
# Procesando Chat de WhatsApp con Tecsil Medellin.txt ...
# Procesando Chat de WhatsApp con Valentina Administración Hotel Mariscal.txt ...
# Procesando Chat de WhatsApp con Ventanas Y Puertas Yenny.txt ...
# Procesando Chat de WhatsApp con Yeison Contador.txt ...
# Procesando Chat de WhatsApp con Zerial.txt ...
# Procesando Chat de WhatsApp con 👑Lorena Ciso.txt ...
# Procesando Chat de WhatsApp con 💫Zenia Saory💫.txt ...
# [        date         time                user  \
#  0   25/10/25  12:47 p. m.   +1 (772) 800-8661
#  1   25/10/25  12:47 p. m.  Vidrios Y Fachadas
#  2   25/10/25  12:47 p. m.   +1 (772) 800-8661
#  3   25/10/25   3:00 p. m.  Vidrios Y Fachadas
#  4   25/10/25   3:00 p. m.  Vidrios Y Fachadas
#  5   25/10/25   3:53 p. m.  Vidrios Y Fachadas
#  6   25/10/25   3:53 p. m.  Vidrios Y Fachadas
#  7   25/10/25   3:53 p. m.  Vidrios Y Fachadas
#  8   25/10/25   3:53 p. m.  Vidrios Y Fachadas
#  9   25/10/25   3:53 p. m.  Vidrios Y Fachadas
#  10  25/10/25   3:53 p. m.  Vidrios Y Fachadas
#  11  25/10/25   3:53 p. m.  Vidrios Y Fachadas
#  12  25/10/25   3:53 p. m.  Vidrios Y Fachadas
#  13  25/10/25   3:53 p. m.  Vidrios Y Fachadas
#  14  25/10/25   3:53 p. m.  Vidrios Y Fachadas
#
#  18  Chat de WhatsApp con +34 610 94 76 16.txt  ,
#         date         time                user  \
#  0   4/08/25   3:45 p. m.     +51 924 523 653
#  1   4/08/25   3:45 p. m.  Vidrios Y Fachadas
#  2   4/08/25   3:46 p. m.     +51 924 523 653
#  3   4/08/25   4:00 p. m.  Vidrios Y Fachadas
#  4   4/08/25   4:00 p. m.  Vidrios Y Fachadas
#  5   4/08/25   4:00 p. m.  Vidrios Y Fachadas
#  6   4/08/25   4:00 p. m.  Vidrios Y Fachadas
#  7   4/08/25   4:03 p. m.     +51 924 523 653
#  8   4/08/25   4:05 p. m.  Vidrios Y Fachadas
#  9   4/08/25   4:05 p. m.     +51 924 523 653
#  10  4/08/25   5:18 p. m.  Vidrios Y Fachadas
#  11  4/08/25   5:18 p. m.  Vidrios Y Fachadas
#  12  4/08/25   5:19 p. m.  Vidrios Y Fachadas
#  13  4/08/25   5:42 p. m.     +51 924 523 653
#  14  4/08/25   5:42 p. m.  Vidrios Y Fachadas
#  15  5/08/25  11:47 a. m.  Vidrios Y Fachadas
#  16  5/08/25  11:48 a. m.  Vidrios Y Fachadas
#  17  5/08/25  11:48 a. m.     +51 924 523 653
#  18  5/08/25  11:49 a. m.  Vidrios Y Fachadas
#
#                                                message  \
#  0   Buenas tardes, para cotizar unas puertas de vi...
#  1   Bienvenido, conoce nuestra variedad de productos:
#  2                                <Multimedia omitido>
#  3                Muy buena stardes como se encuentra?
#  4                                        claro que si
#  5   me comparte si es tan amable los siguientes datos
#  6                                              NOMBRE
#  7   Dagoberto Martínez Nit 11273998530 Dagoberto.0...
#  8   prefecto don diego ya su cotizacion se encuent...
#  9                                             gracias
#  10                                      Don dagoberti
#  11                               <Multimedia omitido>
#  12  Le comparto la cotizacion solicitada, quedamos...
#  13                                            Gracias
#  14  En este momento nuestro grupo de asesores se e...
#  15                         Muy buenos dias como esta?
#  16  don dagoberto que le parecio la cotizacion, ti...
#  17  Buenos días, ya pase la cotización al dueño es...
#  18  perfecto estamos muy pendientes a cualquier in...
#
#                                     file_name
#  0   Chat de WhatsApp con +51 924 523 653.txt
#  1   Chat de WhatsApp con +51 924 523 653.txt
#  2   Chat de WhatsApp con +51 924 523 653.txt
#  3   Chat de WhatsApp con +51 924 523 653.txt
#  4   Chat de WhatsApp con +51 924 523 653.txt
#  5   Chat de WhatsApp con +51 924 523 653.txt
#  6   Chat de WhatsApp con +51 924 523 653.txt
#  7   Chat de WhatsApp con +51 924 523 653.txt
#  8   Chat de WhatsApp con +51 924 523 653.txt
#  9   Chat de WhatsApp con +51 924 523 653.txt
#  10  Chat de WhatsApp con +51 924 523 653.txt
#  11  Chat de WhatsApp con +51 924 523 653.txt
#  12  Chat de WhatsApp con +51 924 523 653.txt
#  13  Chat de WhatsApp con +51 924 523 653.txt
#  14  Chat de WhatsApp con +51 924 523 653.txt
#  15  Chat de WhatsApp con +51 924 523 653.txt
#  16  Chat de WhatsApp con +51 924 523 653.txt
#  17  Chat de WhatsApp con +51 924 523 653.txt
#  18  Chat de WhatsApp con +51 924 523 653.txt  ,
#  7   *_Componentes Clave para un Sistema Eficiente ...
#  8                                         hola buenas
#  9   las medidas de la ventana son 1.65m de ancho x...
#  10  En este momento nuestro grupo de asesores se e...
#  11                                     Muy bueno dias
#  12                               Espero esté muy bien
#  13                     Una pregunta, lo puedo llamar?
#  14                                               hola
#  15       preferiría que primero me den una cotización
#  16                                           si señor
#  17  lo que pensaba era indagar mas acerca del tipo...
#  18  necesito es una ventana que reduzca bastante e...
#  19                                           si señor
#  20                                        se la tengo
#  21           me podría hacer una cotización por favor
#  22                                           si señor
#  23                                                 ok
#  24                               <Multimedia omitido>
#  25                                       Señor Heyner
#  26                          le comparto su cotización
#  27                          vamos a estar muy atentos
#  28                               <Multimedia omitido>
#
#                                     file_name
#  0   Chat de WhatsApp con +57 300 3580743.txt
#  1   Chat de WhatsApp con +57 300 3580743.txt
#  2   Chat de WhatsApp con +57 300 3580743.txt
#  3   Chat de WhatsApp con +57 300 3580743.txt
#  4   Chat de WhatsApp con +57 300 3580743.txt
#  5   Chat de WhatsApp con +57 300 3580743.txt
#  6   Chat de WhatsApp con +57 300 3580743.txt
#  7   Chat de WhatsApp con +57 300 3580743.txt
#  8   Chat de WhatsApp con +57 300 3580743.txt
#  9   Chat de WhatsApp con +57 300 3580743.txt
#  10  Chat de WhatsApp con +57 300 3580743.txt
#  11  Chat de WhatsApp con +57 300 3580743.txt
#  12  Chat de WhatsApp con +57 300 3580743.txt
#  13  Chat de WhatsApp con +57 300 3580743.txt
#  14  Chat de WhatsApp con +57 300 3580743.txt
#  15  Chat de WhatsApp con +57 300 3580743.txt
#  16  Chat de WhatsApp con +57 300 3580743.txt
#  17  Chat de WhatsApp con +57 300 3580743.txt
#  18  Chat de WhatsApp con +57 300 3580743.txt
#  19  Chat de WhatsApp con +57 300 3580743.txt
#  20  Chat de WhatsApp con +57 300 3580743.txt
#  21  Chat de WhatsApp con +57 300 3580743.txt
#  22  Chat de WhatsApp con +57 300 3580743.txt
#  23  Chat de WhatsApp con +57 300 3580743.txt
#  24  Chat de WhatsApp con +57 300 3580743.txt
#  25  Chat de WhatsApp con +57 300 3580743.txt
#  26  Chat de WhatsApp con +57 300 3580743.txt
#  27  Chat de WhatsApp con +57 300 3580743.txt
#  28  Chat de WhatsApp con +57 300 3580743.txt  ,
#         date         time                user  \
#  0  17/10/25  10:41 a. m.     +57 300 3861858
#  1  17/10/25  10:42 a. m.  Vidrios Y Fachadas
#  2  17/10/25  10:43 a. m.     +57 300 3861858
#  3  17/10/25  12:00 p. m.  Vidrios Y Fachadas
#  4  17/10/25  12:00 p. m.  Vidrios Y Fachadas
#
#                                               message  \
#  0                           Buenos días, cómo estás?
#  1  Bienvenido, conoce nuestra variedad de productos:
#  2  Usted préstame servicio de desplazamiento de u...
#  3                                    Muy buenos dias
#  4                    No hacemos ese tipo de trabajos
#
#                                    file_name
#  0  Chat de WhatsApp con +57 300 3861858.txt
#  1  Chat de WhatsApp con +57 300 3861858.txt
#  2  Chat de WhatsApp con +57 300 3861858.txt
#  3  Chat de WhatsApp con +57 300 3861858.txt
#  4  Chat de WhatsApp con +57 300 3861858.txt  ,
#        date         time                user  \
#  0  6/08/25  11:25 a. m.     +57 300 5157021
#  1  6/08/25  11:25 a. m.  Vidrios Y Fachadas
#  2  6/08/25  11:27 a. m.  Vidrios Y Fachadas
#
#                                               message  \
#  0  Hola tengo una puerta de vidrio templado que q...
#  1  Bienvenido, conoce nuestra variedad de productos:
#  2                  no prestamos ese tipo de servicio
#
#                                    file_name
#  0  Chat de WhatsApp con +57 300 5157021.txt
#  1  Chat de WhatsApp con +57 300 5157021.txt
#  2  Chat de WhatsApp con +57 300 5157021.txt  ,
#         date        time                user  \
#  0  29/08/25  7:21 a. m.     +57 300 5215647
#  1  29/08/25  7:33 a. m.  Vidrios Y Fachadas
#  2  29/08/25  7:34 a. m.  Vidrios Y Fachadas
#  3  29/08/25  7:34 a. m.  Vidrios Y Fachadas
#  4  29/08/25  7:34 a. m.  Vidrios Y Fachadas
#  5  29/08/25  7:37 a. m.     +57 300 5215647
#  6  29/08/25  7:37 a. m.     +57 300 5215647
#  7  29/08/25  7:38 a. m.     +57 300 5215647
#
#                                               message  \
#  0                                  Hola, buenos días
#  1  Bienvenido, conoce nuestra variedad de productos:
#  2                                    muy buenos días
#  3                                         como esta?
#  4                            como le podemos ayudar?
#  5                                  Soy Luis Valencia
#  6          De la empresa matriz seguridad industrial
#  7  Eres la persona encargada de compras de seguri...
#
#                                    file_name
#  0  Chat de WhatsApp con +57 300 5215647.txt
#  1  Chat de WhatsApp con +57 300 5215647.txt
#  2  Chat de WhatsApp con +57 300 5215647.txt
#  3  Chat de WhatsApp con +57 300 5215647.txt
#  4  Chat de WhatsApp con +57 300 5215647.txt
#  5  Chat de WhatsApp con +57 300 5215647.txt
#  6  Chat de WhatsApp con +57 300 5215647.txt
#  7  Chat de WhatsApp con +57 300 5215647.txt  ,
#         date         time                user  \
#  0  27/08/25  12:20 p. m.     +57 300 5251823
#  1  27/08/25  12:20 p. m.  Vidrios Y Fachadas
#  2  27/08/25  12:20 p. m.     +57 300 5251823
#  3  27/08/25   2:21 p. m.  Vidrios Y Fachadas
#  4  27/08/25   2:21 p. m.  Vidrios Y Fachadas
#  5  27/08/25   2:21 p. m.  Vidrios Y Fachadas
#  6  27/08/25   2:22 p. m.  Vidrios Y Fachadas
#  7  28/08/25   9:03 a. m.  Vidrios Y Fachadas
#  8  28/08/25   9:04 a. m.  Vidrios Y Fachadas
#  9  28/08/25   9:05 a. m.  Vidrios Y Fachadas
#
#                                               message  \
#  0                                   Hola buenos dias
#  1  Bienvenido, conoce nuestra variedad de productos:
#  2  necesito cotizar con ustedes una puerta de alt...
#  3                    Muy buenas tardes, claro que si
#  4  me comparto los siguientes datos si es tan amable
#  5                                             correo
#  6  mañana en la mañana le estoy compartiendo su p...
#  7                         Muy buenos dias como esta?
#  8                           Eliminaste este mensaje.
#  9                               <Multimedia omitido>
#
#                                    file_name
#  0  Chat de WhatsApp con +57 300 5251823.txt
#  1  Chat de WhatsApp con +57 300 5251823.txt
#  13                    Porfavor me regala la ubicacion
#  14  En este momento nuestro grupo de asesores se e...
#  15                            Programemos una reunión
#  16                                Ok se puede mañana?
#  17                                             Karina
#  18                          Soy en director comercial
#  19  deseas es reunirte con nosotros o ir a conocer...
#  20                  para saber donde te puedo recibir
#  21                       o nos reunimos en su oficina
#  22                                          Estos doa
#  23                                                Dos
#  24  hagamos algo programemos dos reuniones, una en...
#  25                                                 Ok
#  26                             Fechas y hora porfabir
#  27                                  Puede ser mañana?
#  28                    Es que mi jefe está en Medellín
#  29                                             Mañana
#  30  ya tengo la programación, pero como voy a esta...
#  31            y la de planta si puede ser el viernes?
#  32                                 Mañana le consulto
#  33                                    muy buenos días
#  34                                        como estas?
#
#                                     file_name
#  0   Chat de WhatsApp con +57 300 5594233.txt
#  1   Chat de WhatsApp con +57 300 5594233.txt
#  2   Chat de WhatsApp con +57 300 5594233.txt
#  3   Chat de WhatsApp con +57 300 5594233.txt
#  4   Chat de WhatsApp con +57 300 5594233.txt
#  5   Chat de WhatsApp con +57 300 5594233.txt
#  6   Chat de WhatsApp con +57 300 5594233.txt
#  7   Chat de WhatsApp con +57 300 5594233.txt
#  8   Chat de WhatsApp con +57 300 5594233.txt
#  9   Chat de WhatsApp con +57 300 5594233.txt
#  10  Chat de WhatsApp con +57 300 5594233.txt
#  11  Chat de WhatsApp con +57 300 5594233.txt
#  12  Chat de WhatsApp con +57 300 5594233.txt
#  13  Chat de WhatsApp con +57 300 5594233.txt
#  14  Chat de WhatsApp con +57 300 5594233.txt
#  15  Chat de WhatsApp con +57 300 5594233.txt
#  16  Chat de WhatsApp con +57 300 5594233.txt
#  17  Chat de WhatsApp con +57 300 5594233.txt
#  18  Chat de WhatsApp con +57 300 5594233.txt
#  19  Chat de WhatsApp con +57 300 5594233.txt
#  20  Chat de WhatsApp con +57 300 5594233.txt
#  21  Chat de WhatsApp con +57 300 5594233.txt
#  22  Chat de WhatsApp con +57 300 5594233.txt
#  23  Chat de WhatsApp con +57 300 5594233.txt
#  24  Chat de WhatsApp con +57 300 5594233.txt
#  25  Chat de WhatsApp con +57 300 5594233.txt
#  26  Chat de WhatsApp con +57 300 5594233.txt
#  27  Chat de WhatsApp con +57 300 5594233.txt
#  28  Chat de WhatsApp con +57 300 5594233.txt
# ...
#  0                                        Buena tardes
#  1                                <Multimedia omitido>
#  2                                                   P
#  3                                    Julián, que tal.
#  4          Ya está listo el trabajo de las cerraduras
#  5                                      Muchas gracias
#  6                             El lunes paso por ellas
#  7                       Me envía la factura por favor
#  8                                              Dale..
#  9                                <Multimedia omitido>
#  10  En este momento nuestro grupo de asesores se e...
#  11                 Mira Julián, aquí está la factura.
#  12         me comparte el numero de cvuenta por favor
#  13                                        buenos días
#  14                               <Multimedia omitido>
#  15                                  Hola. Buenos días
#  16                                                 ok
#  17                               <Multimedia omitido>
#
#                                              file_name
#  0   Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  1   Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  2   Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  3   Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  4   Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  5   Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  6   Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  7   Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  8   Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  9   Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  10  Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  11  Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  12  Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  13  Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  14  Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  15  Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  16  Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...
#  17  Chat de WhatsApp con SOS LLAVES Y CLAVES OSCAR...  ,
#          date         time                user  \
#  0   20/11/24  12:11 p. m.  Vidrios Y Fachadas
#  1   20/11/24  12:11 p. m.  Vidrios Y Fachadas
#  2   20/11/24  12:11 p. m.  Vidrios Y Fachadas
#  3   20/11/24  12:11 p. m.  Vidrios Y Fachadas
#  4   20/11/24  12:12 p. m.  Vidrios Y Fachadas
#  ..       ...          ...                 ...
#  63  24/09/25   9:48 a. m.     Tecsil Medellin
#  64  24/09/25   9:49 a. m.     Tecsil Medellin
#  65  24/09/25   9:49 a. m.     Tecsil Medellin
#  66  24/09/25   9:49 a. m.     Tecsil Medellin
#  67   7/10/25   8:25 a. m.  Vidrios Y Fachadas
#
#                                                message  \
#  0                                   Muy buenas tardes
#  1       me regalas dos salchichones de silicona negra
#  2            por favor ya mando una moto a recogerlos
#  3                  me dices cuanto es para transferir
#  4                                         mil gracias
#  ..                                                ...
#  63                                   Hola buenos días
#  64                           Espero se encuentre bien
#  65  Es que necesito que me ayude con el salgo que ...
#  66                  Ya que  debo tener la caja al día
#  67                               <Multimedia omitido>
#
#                                     file_name
#  0   Chat de WhatsApp con Tecsil Medellin.txt
#  1   Chat de WhatsApp con Tecsil Medellin.txt
#  2   Chat de WhatsApp con Tecsil Medellin.txt
#  3   Chat de WhatsApp con Tecsil Medellin.txt
#  4   Chat de WhatsApp con Tecsil Medellin.txt
#  ..                                       ...
#  63  Chat de WhatsApp con Tecsil Medellin.txt
#  64  Chat de WhatsApp con Tecsil Medellin.txt
#  65  Chat de WhatsApp con Tecsil Medellin.txt
#  66  Chat de WhatsApp con Tecsil Medellin.txt
#  67  Chat de WhatsApp con Tecsil Medellin.txt
#
#  [68 rows x 5 columns],
#          date         time                                     user  \
#  0    6/10/25  11:29 a. m.                       Vidrios Y Fachadas
#  1    6/10/25  11:29 a. m.                       Vidrios Y Fachadas
#  2    6/10/25  11:29 a. m.                       Vidrios Y Fachadas
#  3    6/10/25  11:30 a. m.                       Vidrios Y Fachadas
#  4    6/10/25   1:18 p. m.  Valentina Administración Hotel Mariscal
#  ..       ...          ...                                      ...
#  65  17/10/25   2:30 p. m.  Valentina Administración Hotel Mariscal
#  66  17/10/25   2:36 p. m.                       Vidrios Y Fachadas
#  67  20/10/25   4:47 p. m.                       Vidrios Y Fachadas
#  68  20/10/25   4:47 p. m.                       Vidrios Y Fachadas
#  69  20/10/25   4:47 p. m.                       Vidrios Y Fachadas
#
#                                                message  \
#  0                                <Multimedia omitido>
#  1                                     Muy buenos dias
#  2   Me informaron de un proyecto de cambio a venta...
#  3         EVENTO: Reunión telefónica ventas acusticas
#  4                                       Buenas tardes
#  ..                                                ...
#  65                          Buenas tardes cómo estás?
#  66                                       Listo señora
#  67                                   Señora Valentina
#  68                                  muy buenas tardes
#  69                                         como esta?
#
#                                              file_name
#  0   Chat de WhatsApp con Valentina Administración ...
#  1   Chat de WhatsApp con Valentina Administración ...
#  2   Chat de WhatsApp con Valentina Administración ...
#  3   Chat de WhatsApp con Valentina Administración ...
#  4   Chat de WhatsApp con Valentina Administración ...
#  ..                                                ...
#  65  Chat de WhatsApp con Valentina Administración ...
#  66  Chat de WhatsApp con Valentina Administración ...
#  67  Chat de WhatsApp con Valentina Administración ...
#  68  Chat de WhatsApp con Valentina Administración ...
#  69  Chat de WhatsApp con Valentina Administración ...
#
#  [70 rows x 5 columns],
#            date         time                      user  \
#  0     15/02/21   2:08 p. m.        Vidrios Y Fachadas
#  1     15/02/21   2:09 p. m.  Ventanas Y Puertas Yenny
#  2     15/02/21   2:09 p. m.  Ventanas Y Puertas Yenny
#  3     22/02/21   4:01 p. m.        Vidrios Y Fachadas
#  4     12/04/21   9:32 a. m.        Vidrios Y Fachadas
#  ...        ...          ...                       ...
#  4840  21/10/25   9:45 a. m.  Ventanas Y Puertas Yenny
#  4841  21/10/25   9:48 a. m.        Vidrios Y Fachadas
#  4842  21/10/25   9:50 a. m.  Ventanas Y Puertas Yenny
#  4843  21/10/25  10:34 a. m.        Vidrios Y Fachadas
#  4844  21/10/25  10:39 a. m.  Ventanas Y Puertas Yenny
#
#                                                  message  \
#  0                                  <Multimedia omitido>
#  1                                                  hola
#  2      mi correo es yeni.chanci@ventanasypuertas.com.co
#  3        Hola Yenni buenas tardes, por favor me cuentas
#  4     Buenos días Yenni, te pregunto la perfilería d...
#  ...                                                 ...
#  4840            si , entonces que hago con el excedente
#  4841                                  Edgar te va pedir
#  4842  ok el restante se lo aplico alo que don edgar ...
#  4843                                          Si señora
#  4844                                                 ok
#
#                                                file_name
#  0     Chat de WhatsApp con Ventanas Y Puertas Yenny.txt
#  1     Chat de WhatsApp con Ventanas Y Puertas Yenny.txt
#  2     Chat de WhatsApp con Ventanas Y Puertas Yenny.txt
#  3     Chat de WhatsApp con Ventanas Y Puertas Yenny.txt
#  4     Chat de WhatsApp con Ventanas Y Puertas Yenny.txt
#  ...                                                 ...
#  4840  Chat de WhatsApp con Ventanas Y Puertas Yenny.txt
#  4841  Chat de WhatsApp con Ventanas Y Puertas Yenny.txt
#  4842  Chat de WhatsApp con Ventanas Y Puertas Yenny.txt
#  4843  Chat de WhatsApp con Ventanas Y Puertas Yenny.txt
#  4844  Chat de WhatsApp con Ventanas Y Puertas Yenny.txt
#
#  [4845 rows x 5 columns],
#          date         time                user  \
#  0   24/04/25   9:58 a. m.  Vidrios Y Fachadas
#  1   24/04/25   9:58 a. m.     Yeison Contador
#  2   24/04/25   9:59 a. m.  Vidrios Y Fachadas
#  3   24/04/25  10:04 a. m.  Vidrios Y Fachadas
#  4   24/04/25  10:04 a. m.  Vidrios Y Fachadas
#  ..       ...          ...                 ...
#  94  10/09/25   3:45 p. m.     Yeison Contador
#  95  10/09/25   3:46 p. m.     Yeison Contador
#  96  10/09/25   3:56 p. m.     Yeison Contador
#  97  10/09/25   4:00 p. m.  Vidrios Y Fachadas
#  98  10/09/25   4:01 p. m.     Yeison Contador
#
#                                                message  \
#  0                                         Buenos dias
#  1   Hola, 👋🏼, dame un momento, mientras tanto, dim...
#  2   ‎Julian Munoz Firma Contable.vcf (archivo adju...
#  3      ya la busco el codigo de ustedes es: 933804736
#  4                                        Gestion.2024
#  ..                                                ...
#  94  Si, dame un momento que ya estoy entrando al s...
#  95                               <Multimedia omitido>
#  96                                      Es correcto ?
#  97                                           si señor
#  98                                          Ok, dale.
#
#                                     file_name
#  0   Chat de WhatsApp con Yeison Contador.txt
#  1   Chat de WhatsApp con Yeison Contador.txt
#  2   Chat de WhatsApp con Yeison Contador.txt
#  3   Chat de WhatsApp con Yeison Contador.txt
#  4   Chat de WhatsApp con Yeison Contador.txt
#  ..                                       ...
#  94  Chat de WhatsApp con Yeison Contador.txt
#  95  Chat de WhatsApp con Yeison Contador.txt
#  96  Chat de WhatsApp con Yeison Contador.txt
#  97  Chat de WhatsApp con Yeison Contador.txt
#  98  Chat de WhatsApp con Yeison Contador.txt
#
#  [99 rows x 5 columns],
#           date         time                user  \
#  0     2/10/20  12:32 p. m.              Zerial
#  1     2/10/20  12:33 p. m.              Zerial
#  2     2/10/20  12:54 p. m.  Vidrios Y Fachadas
#  3     2/10/20   1:01 p. m.              Zerial
#  4     2/10/20   1:01 p. m.              Zerial
#  ..        ...          ...                 ...
#  183  27/10/25   8:39 a. m.              Zerial
#  184  27/10/25   3:44 p. m.              Zerial
#  185  27/10/25   3:45 p. m.  Vidrios Y Fachadas
#  186  27/10/25   3:45 p. m.  Vidrios Y Fachadas
#  187  27/10/25   3:47 p. m.              Zerial
#
#                                                 message  \
#  0    Buenas tardes Paula, hablas Christian Diossa d...
#  1    Juan David Franco me dió tu contacto para que ...
#  2    buenas tardes, Don Christian Diossa, por favor...
#  3                                         Claro que sí
#  4                                 <Multimedia omitido>
#  ..                                                 ...
#  183                                         Igualmente
#  184                               <Multimedia omitido>
#  185                                     Muchas gracias
#  186                                       Linda tardes
#  187                                         Igualmente
#
#                             file_name
#  0    Chat de WhatsApp con Zerial.txt
#  1    Chat de WhatsApp con Zerial.txt
#  2    Chat de WhatsApp con Zerial.txt
#  3    Chat de WhatsApp con Zerial.txt
#  4    Chat de WhatsApp con Zerial.txt
#  ..                               ...
#  183  Chat de WhatsApp con Zerial.txt
#  184  Chat de WhatsApp con Zerial.txt
#  185  Chat de WhatsApp con Zerial.txt
#  186  Chat de WhatsApp con Zerial.txt
#  187  Chat de WhatsApp con Zerial.txt
#
#  [188 rows x 5 columns],
#           date        time                user  \
#  0    23/04/25  5:14 p. m.  Vidrios Y Fachadas
#  1    23/04/25  6:14 p. m.  Vidrios Y Fachadas
#  2    23/04/25  6:14 p. m.  Vidrios Y Fachadas
#  3    23/04/25  6:15 p. m.  Vidrios Y Fachadas
#  4    23/04/25  5:30 p. m.        👑Lorena Ciso
#  ..        ...         ...                 ...
#  338   8/10/25  6:48 a. m.        👑Lorena Ciso
#  339   8/10/25  6:48 a. m.        👑Lorena Ciso
#  340   9/10/25  6:07 p. m.        👑Lorena Ciso
#  341   9/10/25  6:07 p. m.        👑Lorena Ciso
#  342   9/10/25  6:07 p. m.  Vidrios Y Fachadas
#
#                                                 message  \
#  0                                 <Multimedia omitido>
#  1                                   Se cayó la llamada
#  2                                      Mañana te llamo
#  3                           Que estoy entrando a Clase
#  4                                   Hola buenas tardes
#  ..                                                 ...
#  338                               <Multimedia omitido>
#  339  Buenos dias, estas son las facturas que tenemo...
#  340                                        Hola Julian
#  341                Cuéntame cuando nos hacen los pagos
#  342  En este momento nuestro grupo de asesores se e...
#
#                                   file_name
#  0    Chat de WhatsApp con 👑Lorena Ciso.txt
#  1    Chat de WhatsApp con 👑Lorena Ciso.txt
#  2    Chat de WhatsApp con 👑Lorena Ciso.txt
#  3    Chat de WhatsApp con 👑Lorena Ciso.txt
#  4    Chat de WhatsApp con 👑Lorena Ciso.txt
#  ..                                     ...
#  338  Chat de WhatsApp con 👑Lorena Ciso.txt
#  339  Chat de WhatsApp con 👑Lorena Ciso.txt
#  340  Chat de WhatsApp con 👑Lorena Ciso.txt
#  341  Chat de WhatsApp con 👑Lorena Ciso.txt
#  342  Chat de WhatsApp con 👑Lorena Ciso.txt
#
#  [343 rows x 5 columns],
#           date        time                user  \
#  0     3/07/24  1:36 p. m.       💫Zenia Saory💫
#  1     3/07/24  1:37 p. m.  Vidrios Y Fachadas
#  2     3/07/24  1:42 p. m.  Vidrios Y Fachadas
#  3     3/07/24  1:42 p. m.  Vidrios Y Fachadas
#  4     3/07/24  1:53 p. m.       💫Zenia Saory💫
#  ..        ...         ...                 ...
#  301  12/02/25  3:54 p. m.       💫Zenia Saory💫
#  302  12/02/25  3:55 p. m.  Vidrios Y Fachadas
#  303  17/09/25  8:40 p. m.       💫Zenia Saory💫
#  304  17/09/25  8:41 p. m.  Vidrios Y Fachadas
#  305  17/09/25  8:41 p. m.  Vidrios Y Fachadas
#
#                                                 message  \
#  0                                         Buena tarde.
#  1    Gracias por comunicarte con Vidrios y Fachadas...
#  2                                    Muy buenas tardes
#  3                               Como podemos servirle?
#  4                                 <Multimedia omitido>
#  ..                                                 ...
#  301                                    Ok..lo solicitó
#  302                                        mil gracias
#  303                                      Buena tarde..
#  304  Bienvenido, conoce nuestra variedad de productos:
#  305  En este momento nuestro grupo de asesores se e...
#
#                                    file_name
#  0    Chat de WhatsApp con 💫Zenia Saory💫.txt
#  1    Chat de WhatsApp con 💫Zenia Saory💫.txt
#  2    Chat de WhatsApp con 💫Zenia Saory💫.txt
#  3    Chat de WhatsApp con 💫Zenia Saory💫.txt
#  4    Chat de WhatsApp con 💫Zenia Saory💫.txt
#  ..                                      ...
#  301  Chat de WhatsApp con 💫Zenia Saory💫.txt
#  302  Chat de WhatsApp con 💫Zenia Saory💫.txt
#  303  Chat de WhatsApp con 💫Zenia Saory💫.txt
#  304  Chat de WhatsApp con 💫Zenia Saory💫.txt
#  305  Chat de WhatsApp con 💫Zenia Saory💫.txt
#
#  [306 rows x 5 columns]]

# %%
# Unir todos los chats en un solo DataFrame
df_all = pd.concat(all_chats, ignore_index=True)

# Eliminar mensajes del sistema (como “Los mensajes y las llamadas están cifrados...”)
df_all = df_all[~df_all["message"].str.contains("cifrados de extremo a extremo", na=False)]

# Normalizar nombres y fechas
df_all["date"] = pd.to_datetime(df_all["date"], dayfirst=True, errors="coerce")
df_all["time"] = df_all["time"].str.replace(" ", " ")  # limpiar espacios Unicode

# Guardar resultado limpio
output_file = clean_path / "whatsapp_clean.csv"
df_all.to_csv(output_file, index=False, encoding="utf-8-sig")

print(f"Archivo limpio guardado en: {output_file}")
print(f"Total de mensajes procesados: {len(df_all)}")

# Vista previa
df_all.head(10)
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_29232\2412316149.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all["date"] = pd.to_datetime(df_all["date"], dayfirst=True, errors="coerce")
# Archivo limpio guardado en: ..\data\cleaned\whatsapp_clean.csv
# Total de mensajes procesados: 44993
#         date         time                user  \
# 0 2025-10-25  12:47 p. m.   +1 (772) 800-8661
# 1 2025-10-25  12:47 p. m.  Vidrios Y Fachadas
# 2 2025-10-25  12:47 p. m.   +1 (772) 800-8661
# 3 2025-10-25   3:00 p. m.  Vidrios Y Fachadas
# 4 2025-10-25   3:00 p. m.  Vidrios Y Fachadas
# 5 2025-10-25   3:53 p. m.  Vidrios Y Fachadas
# 6 2025-10-25   3:53 p. m.  Vidrios Y Fachadas
# 7 2025-10-25   3:53 p. m.  Vidrios Y Fachadas
# 8 2025-10-25   3:53 p. m.  Vidrios Y Fachadas
# 9 2025-10-25   3:53 p. m.  Vidrios Y Fachadas
#
#                                              message  \
# 0                                              Hola!
# 1  Bienvenido, conoce nuestra variedad de productos:
# 2  Estoy buscando ventanas corredizas en aluminio...
# 3                                           Si señor
# 4                                     Se las tenemos
# 5                               <Multimedia omitido>
# 6                               <Multimedia omitido>
# 7                               <Multimedia omitido>
# 8                               <Multimedia omitido>
# 9                               <Multimedia omitido>
#
#                                     file_name
# 0  Chat de WhatsApp con +1 (772) 800-8661.txt
# 1  Chat de WhatsApp con +1 (772) 800-8661.txt
# 2  Chat de WhatsApp con +1 (772) 800-8661.txt
# 3  Chat de WhatsApp con +1 (772) 800-8661.txt
# 4  Chat de WhatsApp con +1 (772) 800-8661.txt
# 5  Chat de WhatsApp con +1 (772) 800-8661.txt
# 6  Chat de WhatsApp con +1 (772) 800-8661.txt
# 7  Chat de WhatsApp con +1 (772) 800-8661.txt
# 8  Chat de WhatsApp con +1 (772) 800-8661.txt
# 9  Chat de WhatsApp con +1 (772) 800-8661.txt

# %%
# =========================================================
# SmartChat Insight
# Análisis de clientes recurrentes, perdidos y productos más solicitados
# =========================================================

# Importar librerías
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# Definir rutas
clean_path = Path("../data/cleaned/whatsapp_clean.csv")
output_path = Path("../data/outputs/")
output_path.mkdir(parents=True, exist_ok=True)

# Cargar datos limpios
df = pd.read_csv(clean_path)
df["date"] = pd.to_datetime(df["date"], errors="coerce")

print("Datos cargados correctamente")
print(f"Total de mensajes: {len(df)}")
df.head(5)
# Out:
# Datos cargados correctamente
# Total de mensajes: 44993
#         date         time                user  \
# 0 2025-10-25  12:47 p. m.   +1 (772) 800-8661
# 1 2025-10-25  12:47 p. m.  Vidrios Y Fachadas
# 2 2025-10-25  12:47 p. m.   +1 (772) 800-8661
# 3 2025-10-25   3:00 p. m.  Vidrios Y Fachadas
# 4 2025-10-25   3:00 p. m.  Vidrios Y Fachadas
#
#                                              message  \
# 0                                              Hola!
# 1  Bienvenido, conoce nuestra variedad de productos:
# 2  Estoy buscando ventanas corredizas en aluminio...
# 3                                           Si señor
# 4                                     Se las tenemos
#
#                                     file_name
# 0  Chat de WhatsApp con +1 (772) 800-8661.txt
# 1  Chat de WhatsApp con +1 (772) 800-8661.txt
# 2  Chat de WhatsApp con +1 (772) 800-8661.txt
# 3  Chat de WhatsApp con +1 (772) 800-8661.txt
# 4  Chat de WhatsApp con +1 (772) 800-8661.txt

# %%
# Identificar participantes únicos
clientes = df["user"].unique()
print(f"Total de usuarios detectados: {len(clientes)}")

# Calcular número de mensajes, primera y última fecha
activity = (
    df.groupby("user")
      .agg(
          mensajes=("message", "count"),
          primer_contacto=("date", "min"),
          ultimo_contacto=("date", "max")
      )
      .reset_index()
)

# Calcular días desde el último mensaje
activity["dias_desde_ultimo"] = (df["date"].max() - activity["ultimo_contacto"]).dt.days

# Clasificar clientes
def clasificar_cliente(dias):
    if dias <= 15:
        return "Frecuente"
    elif dias <= 45:
        return "Inactivo reciente"
    else:
        return "Perdido"

activity["estado"] = activity["dias_desde_ultimo"].apply(clasificar_cliente)

activity.head(10)
# Out:
# Total de usuarios detectados: 313
#                 user  mensajes primer_contacto ultimo_contacto  \
# 0  +1 (772) 800-8661         9      2025-10-25      2025-10-27
# 1   +34 610 94 76 16         9      2025-10-22      2025-10-22
# 2    +51 924 523 653         6      2025-08-04      2025-08-05
# 3    +57 300 2258585         8      2025-09-18      2025-10-02
# 4    +57 300 3542763         8      2025-09-25      2025-09-26
# 5    +57 300 3580743         9      2025-09-03      2025-10-15
# 6    +57 300 3861858         2      2025-10-17      2025-10-17
# 7    +57 300 5157021         1      2025-08-06      2025-08-06
# 8    +57 300 5215647         4      2025-08-29      2025-08-29
# 9    +57 300 5251823         2      2025-08-27      2025-08-27
#
#    dias_desde_ultimo             estado
# 0                  0          Frecuente
# 1                  5          Frecuente
# 2                 83            Perdido
# 3                 25  Inactivo reciente
# 4                 31  Inactivo reciente
# 5                 12          Frecuente
# 6                 10          Frecuente
# 7                 82            Perdido
# 8                 59            Perdido
# 9                 61            Perdido

# %%
# Palabras clave de productos (se adaptan según cada negocio)
productos = [
    "vidrio", "fachada", "aluminio", "puerta", "ventana",
    "baño", "división", "pasamanos", "pérgola", "instalador"
]

# Contar menciones de cada producto
conteo_productos = {}
for p in productos:
    conteo_productos[p] = df["message"].str.contains(p, case=False, na=False).sum()

df_productos = pd.DataFrame(list(conteo_productos.items()), columns=["producto", "menciones"])
df_productos = df_productos.sort_values(by="menciones", ascending=False)
df_productos
# Out:
#      producto  menciones
# 0      vidrio        667
# 3      puerta        467
# 4     ventana        420
# 1     fachada        248
# 7   pasamanos        175
# 2    aluminio         81
# 9  instalador         53
# 5        baño         48
# 8     pérgola          6
# 6    división          5

# %%
# Gráfico de clientes según estado
plt.figure(figsize=(6,4))
activity["estado"].value_counts().plot(kind="bar")
plt.title("Distribución de Clientes por Estado")
plt.xlabel("Estado")
plt.ylabel("Número de clientes")
plt.show()

# Gráfico de productos más mencionados
plt.figure(figsize=(8,4))
df_productos.plot(kind="barh", x="producto", y="menciones", legend=False)
plt.title("Productos más mencionados en los chats")
plt.xlabel("Número de menciones")
plt.ylabel("Producto")
plt.show()

# %%
activity.to_csv(output_path / "clientes.csv", index=False, encoding="utf-8-sig")
df_productos.to_csv(output_path / "productos.csv", index=False, encoding="utf-8-sig")

print("✅ Archivos exportados para Power BI:")
print(f"- {output_path / 'clientes.csv'}")
print(f"- {output_path / 'productos.csv'}")
# Out:
# ✅ Archivos exportados para Power BI:
# - ..\data\outputs\clientes.csv
# - ..\data\outputs\productos.csv

# %%
# =========================================================
# SmartChat Insight
# Exportación y preparación de datasets finales para Power BI
# =========================================================

# Importar librerías
import pandas as pd
from pathlib import Path

# Rutas de entrada y salida
input_path = Path("../data/outputs/")
final_path = Path("../data/outputs/final/")
final_path.mkdir(parents=True, exist_ok=True)

# Cargar archivos de análisis previos
clientes = pd.read_csv(input_path / "clientes.csv")
productos = pd.read_csv(input_path / "productos.csv")

print(f"Clientes cargados: {len(clientes)} registros")
print(f"Productos cargados: {len(productos)} registros")

clientes.head(5)
# Out:
# Clientes cargados: 313 registros
# Productos cargados: 10 registros
#                 user  mensajes primer_contacto ultimo_contacto  \
# 0  +1 (772) 800-8661         9      2025-10-25      2025-10-27
# 1   +34 610 94 76 16         9      2025-10-22      2025-10-22
# 2    +51 924 523 653         6      2025-08-04      2025-08-05
# 3    +57 300 2258585         8      2025-09-18      2025-10-02
# 4    +57 300 3542763         8      2025-09-25      2025-09-26
#
#    dias_desde_ultimo             estado
# 0                  0          Frecuente
# 1                  5          Frecuente
# 2                 83            Perdido
# 3                 25  Inactivo reciente
# 4                 31  Inactivo reciente

# %%
# Normalizar nombres de columnas a formato uniforme para Power BI
clientes.columns = clientes.columns.str.lower().str.replace(" ", "_")
productos.columns = productos.columns.str.lower().str.replace(" ", "_")

# Asegurar tipos de datos correctos
clientes["primer_contacto"] = pd.to_datetime(clientes["primer_contacto"], errors="coerce")
clientes["ultimo_contacto"] = pd.to_datetime(clientes["ultimo_contacto"], errors="coerce")
clientes["dias_desde_ultimo"] = clientes["dias_desde_ultimo"].astype(int)

# %%
# Crear un resumen con totales por estado
resumen_clientes = (
    clientes.groupby("estado")
    .agg(
        total_clientes=("user", "count"),
        promedio_mensajes=("mensajes", "mean"),
        dias_promedio_inactividad=("dias_desde_ultimo", "mean")
    )
    .reset_index()
)

# Agregar fecha de generación del reporte
from datetime import datetime
resumen_clientes["fecha_reporte"] = datetime.now().strftime("%Y-%m-%d")
resumen_clientes
# Out:
#               estado  total_clientes  promedio_mensajes  \
# 0          Frecuente              83         439.602410
# 1  Inactivo reciente             108          40.092593
# 2            Perdido             122          34.229508
#
#    dias_promedio_inactividad fecha_reporte
# 0                   6.987952    2025-11-02
# 1                  28.962963    2025-11-02
# 2                  81.655738    2025-11-02

# %%
clientes.to_csv(final_path / "clientes_powerbi.csv", index=False, encoding="utf-8-sig")
productos.to_csv(final_path / "productos_powerbi.csv", index=False, encoding="utf-8-sig")
resumen_clientes.to_csv(final_path / "resumen_clientes.csv", index=False, encoding="utf-8-sig")

print("Archivos finales generados:")
for file in final_path.glob("*.csv"):
    print("-", file.name)
# Out:
# Archivos finales generados:
# - clientes_powerbi.csv
# - productos_powerbi.csv
# - resumen_clientes.csv
